# %%
import pandas as pd

# %%
df1 = pd.read_csv("flickr_data.csv")
df2 = pd.read_csv("flickr_data1.csv")
df3 = pd.read_csv("more_data.csv")

# %%
df = pd.concat([df1, df2, df3])

# %%
df
# Out:
#                                               Photo URL           Date Taken  \
# 0     https://live.staticflickr.com/65535/5355604611...  2024-02-27 13:14:24
# 1     https://live.staticflickr.com/65535/5330595486...  2022-11-18 12:41:48
# 2     https://live.staticflickr.com/65535/5318654669...  2023-09-14 11:59:27
# 3     https://live.staticflickr.com/65535/5318136907...  2023-09-12 08:38:56
# 4     https://live.staticflickr.com/65535/5318215074...  2023-09-12 08:38:57
# ...                                                 ...                  ...
# 7586  https://live.staticflickr.com/2457/5705635543_...  2011-04-29 20:44:57
# 7587  https://live.staticflickr.com/4095/4895217131_...  1938-01-01 00:00:00
# 7588  https://live.staticflickr.com/4119/4821090836_...  2005-06-03 00:36:19
# 7589  https://live.staticflickr.com/4001/4399989180_...  2004-01-26 09:41:01
# 7590  https://live.staticflickr.com/2742/4399989108_...  2004-01-26 09:29:23
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11361 entries, 0 to 7590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Photo URL   11361 non-null  object
#  1   Date Taken  11361 non-null  object
#  2   Latitude    11361 non-null  float64
#  3   Longitude   11361 non-null  float64
#  4   tag         11361 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 532.5+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4309 entries, 0 to 7590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Photo URL   4309 non-null   object
#  1   Date Taken  4309 non-null   object
#  2   Latitude    4309 non-null   float64
#  3   Longitude   4309 non-null   float64
#  4   tag         4309 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 202.0+ KB

# %%
df_with_correct_geotags =  df[(df['Latitude'] != 0) & (df['Longitude'] != 0)]

# %%
df_with_correct_geotags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2821 entries, 1 to 7590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Photo URL   2821 non-null   object
#  1   Date Taken  2821 non-null   object
#  2   Latitude    2821 non-null   float64
#  3   Longitude   2821 non-null   float64
#  4   tag         2821 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 132.2+ KB

# %%
missing_lat_lon = df[(df['Latitude'] == 0) & (df['Longitude'] == 0)]

# %%
missing_lat_lon.groupby("tag").count()
# Out:
#                     Photo URL  Date Taken  Latitude  Longitude
# tag
# amsterdam+street           79          79        79         79
# crowded street             22          22        22         22
# festival                   94          94        94         94
# glasgow+street             65          65        65         65
# london+street             193         193       193        193
# men outside                 1           1         1          1
# people outside             57          57        57         57
# rain                       36          36        36         36
# spring fashion             13          13        13         13
# stockholm+street           66          66        66         66
# street amsterdam           26          26        26         26
# street festival            86          86        86         86
# street gothenburg           1           1         1          1
# street london             161         161       161        161
# ...

# %%
df.replace(0, None, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4309 entries, 0 to 7590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Photo URL   4309 non-null   object
#  1   Date Taken  4309 non-null   object
#  2   Latitude    2821 non-null   object
#  3   Longitude   2821 non-null   object
#  4   tag         4309 non-null   object
# dtypes: object(5)
# memory usage: 202.0+ KB

# %%
def fillna_mode(group):
    return group.fillna(group.mode()[0])

# %%
df['Latitude'].fillna(57.708870, inplace=True)
# Out:
# /tmp/ipykernel_7139/3422620828.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Latitude'].fillna(57.708870, inplace=True)
# /tmp/ipykernel_7139/3422620828.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Latitude'].fillna(57.708870, inplace=True)

# %%
df
# Out:
#                                               Photo URL           Date Taken  \
# 0     https://live.staticflickr.com/65535/5355604611...  2024-02-27 13:14:24
# 1     https://live.staticflickr.com/65535/5330595486...  2022-11-18 12:41:48
# 2     https://live.staticflickr.com/65535/5318654669...  2023-09-14 11:59:27
# 3     https://live.staticflickr.com/65535/5318136907...  2023-09-12 08:38:56
# 4     https://live.staticflickr.com/65535/5318215074...  2023-09-12 08:38:57
# ...                                                 ...                  ...
# 7583  https://live.staticflickr.com/2309/5705644585_...  2011-04-29 20:58:00
# 7584  https://live.staticflickr.com/2035/5705642991_...  2011-04-29 20:57:40
# 7585  https://live.staticflickr.com/2108/5705641307_...  2011-04-29 20:56:20
# 7586  https://live.staticflickr.com/2457/5705635543_...  2011-04-29 20:44:57
# 7590  https://live.staticflickr.com/2742/4399989108_...  2004-01-26 09:29:23
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4309 entries, 0 to 7590
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Photo URL   4309 non-null   object
#  1   Date Taken  4309 non-null   object
#  2   Latitude    4309 non-null   float64
#  3   Longitude   4309 non-null   float64
#  4   tag         4309 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 202.0+ KB

# %%
def fetch_photo_from_path(img_path):
    with urllib.request.urlopen(img_path) as response:
        img_array = np.array(bytearray(response.read()), dtype=np.uint8)

    # Decode the image
    image = cv2.imdecode(img_array, -1)
    return image

# %%
from utils import fetch_photo_from_path, detect_humans
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/hackathon/jackavenv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[59], line 1
#     from utils import fetch_photo_from_path, detect_humans
#
#   File ~/Desktop/hackathon/thejackieproject/utils.py:126
#     return detected_images
#     ^
# SyntaxError: 'return' outside function

# %%
from project2 import ImageClassification

for x in range(len(df)):
    img_path = df.iloc[x]["Photo URL"]
    ind = x
    img_class = ImageClassification(image_url = img_path, idnr = ind)
# Out:
# Model loaded successfully.
# 0 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# 0 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# 0 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# Saving a human
# 1 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# 0 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# Saving a human
# 1 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# Saving a human
# Saving a human
# 2 images have been saved to /home/milena/Desktop/hackathon/thejackieproject\output_folder.
# Model loaded successfully.
# ...

# %%
df.head()
# Out:
#                                            Photo URL           Date Taken  \
# 0  https://live.staticflickr.com/65535/5355604611...  2024-02-27 13:14:24
# 1  https://live.staticflickr.com/65535/5330595486...  2022-11-18 12:41:48
# 2  https://live.staticflickr.com/65535/5318654669...  2023-09-14 11:59:27
# 3  https://live.staticflickr.com/65535/5318136907...  2023-09-12 08:38:56
# 4  https://live.staticflickr.com/65535/5318215074...  2023-09-12 08:38:57
#
#     Latitude  Longitude               tag
# 0  57.708870  11.974560  stockholm+street
# 1  39.275161 -76.624573  stockholm+street
# 2  57.708870  11.974560  stockholm+street
# 3  57.708870  11.974560  stockholm+street
# 4  57.708870  11.974560  stockholm+street
